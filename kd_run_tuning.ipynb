# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Training

# %%
# !python /content/drive/MyDrive/Machine_Learning_Models/pytorch-cifar100/knowledge_distillation_train.py -gpu -teacher /content/drive/MyDrive/Machine_Learning_Models/pytorch-cifar100/runs/vgg16/vgg16-164-best.pth -student /content/drive/MyDrive/Machine_Learning_Models/pytorch-cifar100/runs/mobilenet/mobilenet-124-best.pth -lr 0.001 -b 64
# Out:
# Streaming output truncated to the last 5000 lines.
# |       from small pool |     456    |     552    |   29997 K  |   29996 K  |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |      32    |      32    |      32    |       0    |
# |       from large pool |      12    |      12    |      12    |       0    |
# |       from small pool |      20    |      20    |      20    |       0    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |      20    |      27    |   17181 K  |   17181 K  |
# |       from large pool |       6    |      10    |    6785 K  |    6785 K  |
# |       from small pool |      14    |      21    |   10395 K  |   10395 K  |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# ...

# %% [markdown]
# ## Test with CPU

# %%
# !python /content/drive/MyDrive/Knowledge-Distillation/knowledge_distillation_test.py -weights /content/drive/MyDrive/Knowledge-Distillation/runs/kd_mobilenet/tuning/kd_mobilenet-134-best.pth
# Out:
# ...
# 100% 169001437/169001437 [00:03<00:00, 48927502.29it/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# MobileNet(
#   (stem): Sequential(
#     (0): BasicConv2d(
#       (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (1): DepthSeperabelConv2d(
#       (depthwise): Sequential(
# ...

# %% [markdown]
# ## Test with GPU

# %%
# !python /content/drive/MyDrive/Knowledge-Distillation/knowledge_distillation_test.py -gpu -weights /content/drive/MyDrive/Knowledge-Distillation/runs/kd_mobilenet/tuning/kd_mobilenet-134-best.pth
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# MobileNet(
#   (stem): Sequential(
#     (0): BasicConv2d(
#       (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (1): DepthSeperabelConv2d(
#       (depthwise): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
# ...
